# %%
import pandas as pd

number = pd.DataFrame({"yes": [50, 21], "No": [131, 2]})

print(number)
# Out:
#    yes   No
# 0   50  131
# 1   21    2

# %%
import pandas as pd

person = pd.DataFrame({"Bob": ["i like it", "It was awful"], "Su": ["Pretty good", 'B']})
print(person)
# Out:
#             Bob           Su
# 0     i like it  Pretty good
# 1  It was awful            B

# %%
import pandas as pd


persons = pd.DataFrame({"Bob": ["ilke it", "I was awful"], 
                        "Su": ["pretty goog", "Bland"]},
                        index = ["Product A", "Product B"])

print(persons)
# Out:
#                    Bob           Su
# Product A      ilke it  pretty goog
# Product B  I was awful        Bland

# %%
import pandas as pd


numbers = pd.Series([1, 2, 3, 4, 5])

print(numbers)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
import pandas as pd

data = pd.Series([30, 35, 40], index=['2015 Seles', '2016 Seles', '2017 Seles'], name= "Product A")

print(data)
# Out:
# 2015 Seles    30
# 2016 Seles    35
# 2017 Seles    40
# Name: Product A, dtype: int64

# %%
import pandas as pd

# Let's first create a small fake CSV file for testing
data = """country,points,price,winery
        Italy,87,20,Castello di Gabbiano
        Portugal,90,15,Quinta dos Avidagos
        US,85,30,Ste. Michelle
        Spain,88,12,Bodegas LAN
        """

# Save the fake data to a CSV file
with open("wine_reviews.csv", "w") as f:
    f.write(data)

# Now read the CSV file into a DataFrame
wine_reviews = pd.read_csv("wine_reviews.csv")

# Show the first few rows
print("📊 First rows of the dataset:")
print(wine_reviews.head(), "\n")

# Show the shape (number of rows and columns)
print("📏 Shape of the dataset:", wine_reviews.shape)
# Out:
# 📊 First rows of the dataset:
#     country  points  price                winery
# 0     Italy      87     20  Castello di Gabbiano
# 1  Portugal      90     15   Quinta dos Avidagos
# 2        US      85     30         Ste. Michelle
# 3     Spain      88     12           Bodegas LAN
#
# 📏 Shape of the dataset: (4, 4)
